# %% [markdown]
# ## Exercício 1
#
# Agora que já estamos um pouco familiarizados com as bibliotecas Requests e BeautifulSoup, vamos fazer o primeiro exercício dessa aula. Tente integrar as duas bibliotecas para podermos trabalhar com o Web Scraping propriamente dito. Ou seja, inserir o conteúdo da gerado do Requests da URL no BeautifulSoup.

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://pixabay.com/pt/photos/'
payload = {'q': 'gatinhos felizes'}

r = requests.get(url, params=payload)
soup = BeautifulSoup(r.content, 'html.parser')

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="pt" prefix="og: http://ogp.me/ns#">
#  <head>
#   <meta charset="utf-8">
#    <link href="/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57">
#     <link href="/apple-touch-icon-60x60.png" rel="apple-touch-icon" sizes="60x60">
#      <link href="/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72">
#       <link href="/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76">
#        <link href="/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114">
#         <link href="/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120">
#          <link href="/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144">
#           <link href="/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152">
#            <link href="/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180">
#             <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png">
#              <link href="/android-chrome-192x192.png" rel="icon" sizes="192x192" type="image/png">
#               <link href="/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png">
#                <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png">
#                 <link href="/manifest.json" rel="manifest">
#                  <link color="#4ea64e" href="/safari-pinned-tab.svg" rel="mask-icon">
#                   <meta content="#4ea64e" name="msapplication-TileColor">
#                    <meta content="/mstile-144x144.png" name="msapplication-TileImage">
#                     <meta content="#4ea64e" name="theme-color">
#                      <link href="https://pixabay.com/static/misc/opensearch.xml" rel="search" title="Pixabay" type="application/opensearchdescription+xml">
#                       <meta content="width=device-width, initial-scale=1" name="viewport">
#                        <link href="/static/css/base30.min.css" rel="stylesheet">
#                         <!--[if lt IE 9]><script src="//cdnjs.cloudflare.com/ajax/libs/respond.js/1.4.2/respond.min.js"></script><![endif]-->
#                         <title>
#                          Gatinhos, Felizes - Imagens gratis no Pixabay
#                         </title>
#                         <meta content="Baixe imagens grátis sobre Gatinhos, Felizes da biblioteca do Pixabay de mais de 890.000 fotos, ilustrações e vetores de domínio público" name="description">
#                          <meta content="noindex,follow" name="robots">
#                          </meta>
#                         </meta>
#                        </link>
#                       </meta>
#                      </link>
#                     </meta>
#                    </meta>
#                   </meta>
#                  </link>
#                 </link>
#                </link>
#               </link>
#              </link>
#             </link>
#            </link>
#           </link>
#          </link>
#         </link>
#        </link>
#       </link>
#      </link>
#     </link>
#    </link>
#   </meta>
#  </head>
#  <body>
#   <div id="wrapper">
#    <div id="header">
#     <div id="header_inner">
#      <div class="pure-menu pure-menu-horizontal pure-menu-open">
#       <ul>
#        <li class="pure-dropdown hide-xs hide-sm hide-md">
#         <a href="/pt/editors_choice/">
#          Explorar
#          <i class="arrow">
#          </i>
#         </a>
#         <ul class="pure-menu-children">
#          <li class="mm_inc">
#           <a href="/pt/editors_choice/">
#            Escolha do Editor
#           </a>
#          </li>
#          <li class="mm_inc">
#           <a href="/pt/photos/?order=popular">
#            Imagens
#           </a>
#          </li>
#          <li class="mm_inc mm_sep">
#           <a href="/pt/videos/">
#            Videos
#           </a>
#          </li>
#          <li class="pure-menu-separator">
#          </li>
#          <li class="mm_inc">
#           <a href="/pt/users/">
#            Fotógrafos
#           </a>
#          </li>
#          <li class="mm_inc mm_sep">
#           <a href="/pt/cameras/">
#            Câmeras
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="hide-xs hide-sm hide-md mum_inc">
#         <a href="/pt/accounts/register/">
#          Cadastrar-se
#         </a>
#        </li>
#        <li class="hide-xs hide-sm hide-md hide-lg mum_inc">
#         <a href="/pt/accounts/login/?next=/pt/photos/%3Fq%3Dgatinhos%2Bfelizes">
#          Efetuar login
#         </a>
#        </li>
#        <li class="pure-dropdown hide-lg hide-xl">
#         <a>
#          <i class="icon icon_menu_user">
#          </i>
#         </a>
#         <ul class="pure-menu-children" id="mobile_user_menu">
#         </ul>
#        </li>
#        <li class="toggle_mobile_search pure-dropdown hide-md hide-lg hide-xl">
#         <a>
#          <i class="icon icon_menu_loupe">
#          </i>
#         </a>
#        </li>
#        <li class="pure-dropdown hide-xs hide-sm hide-md">
#         <a>
#          <i class="icon icon_menu_dots">
#          </i>
#         </a>
#         <ul class="pure-menu-children">
#          <li class="mm_inc">
#           <a href="/pt/service/faq/">
#            FAQ
#           </a>
#          </li>
#          <li class="mm_inc">
#           <a href="/pt/forum/">
#            Fórum
#           </a>
#          </li>
#          <li class="mm_inc">
#           <a href="/pt/blog/">
#            Blog
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="pure-dropdown hide-lg hide-xl">
#         <a>
#          <i class="icon icon_menu_bars">
#          </i>
#         </a>
#         <ul class="pure-menu-children" id="mobile_menu">
#         </ul>
#        </li>
#       </ul>
#      </div>
#      <a class="hover_opacity" href="/" id="logo">
#      </a>
#      <form action="/pt/photos/" class="media_search header_search" method="get">
#       <input type="submit" value=" ">
#        <div class="dd_box">
#         <span class="image_type" style="margin-right:5px">
#          Todas as imagens
#         </span>
#         <i class="arrow">
#         </i>
#        </div>
#        <div class="pure-form bubble se">
#         <table>
#          <tr>
#           <th>
#            Tipo de mídia
#           </th>
#           <td>
#            <label>
#             <input checked="" name="image_type" type="radio" value="">
#              Todas as imagens
#             </input>
#            </label>
#            <label>
#             <input name="image_type" type="radio" value="photo">
#              Fotos
#             </input>
#            </label>
#            <label>
#             <input name="image_type" type="radio" value="vector">
#              Imagens vetoriais
#             </input>
#            </label>
#            <label>
#             <input name="image_type" type="radio" value="illustration">
#              Ilustrações
#             </input>
#            </label>
#            <label>
#             <input name="image_type" type="radio" value="video">
#              Videos
#             </input>
#            </label>
#           </td>
#          </tr>
#          <tr class="image_option">
#           <th>
#            Orientação
#           </th>
#           <td>
#            <label>
#             <input name="orientation" type="checkbox" value="horizontal">
#              Horizontal
#             </input>
#            </label>
#            <label>
#             <input name="orientation" type="checkbox" value="vertical">
#              Vertical
#             </input>
#            </label>
#           </td>
#          </tr>
#          <tr class="video_option">
#           <th>
#            Efeitos
#           </th>
#           <td>
#            <label>
#             <input name="animation" type="checkbox" value="1">
#              Animação
#             </input>
#            </label>
#            <label>
#             <input name="slow_motion" type="checkbox" value="1">
#              Câmera lenta
#             </input>
#            </label>
#            <label>
#             <input name="time_lapse" type="checkbox" value="1">
#              Time lapse
#             </input>
#            </label>
#           </td>
#          </tr>
#          <tr>
#           <th style="vertical-align:middle">
#            Categoria
#           </th>
#           <td>
#            <select name="cat">
#             <option selected="" value="">
#              Todas
#             </option>
#             <option value="food">
#              Alimentos/Bebidas
#             </option>
#             <option value="animals">
#              Animais
#             </option>
#             <option value="buildings">
#              Arquitetura/Edifícios
#             </option>
#             <option value="fashion">
#              Beleza/Moda
#             </option>
#             <option value="science">
#              Ciência/Tecnologia
#             </option>
#             <option value="computer">
#              Computação/Comunicação
#             </option>
#             <option value="education">
#              Educação
#             </option>
#             <option value="feelings">
#              Emoções
#             </option>
#             <option value="sports">
#              Esportes
#             </option>
#             <option value="industry">
#              Industria/Oficio
#             </option>
#             <option value="places">
#              Lugares/Monumentos
#             </option>
#             <option value="music">
#              Música
#             </option>
#             <option value="nature">
#              Natureza/Paisagens
#             </option>
#             <option value="business">
#              Negócios/Finanças
#             </option>
#             <option value="people">
#              Pessoas
#             </option>
#             <option value="backgrounds">
#              Plano de Fundo/Texturas
#             </option>
#             <option value="religion">
#              Religião
#             </option>
#             <option value="health">
#              Saúde/Medicinal
#             </option>
#             <option value="transportation">
#              Transporte/Tráfego
#             </option>
#             <option value="travel">
#              Viagem/Férias
#             </option>
#            </select>
#           </td>
#          </tr>
#          <tr class="image_option">
#           <th style="vertical-align:middle">
#            Maior que
#           </th>
#           <td style="ccolor:#777">
#            <input name="min_width" placeholder="Largura" type="text" value="">
#             <span class="times">
#              ×
#             </span>
#             <input name="min_height" placeholder="Altura" type="text" value="">
#              px
#             </input>
#            </input>
#           </td>
#          </tr>
#          <tr class="image_option">
#           <th>
#            Preto e branco
#           </th>
#           <td>
#            <label>
#             <input name="colors" type="checkbox" value="transparent">
#              Transparente
#             </input>
#            </label>
#            <input class="cf_grayscale" id="cf_grayscale" name="colors" style="float:none" type="checkbox" value="grayscale">
#             <label for="cf_grayscale" style="display:inline">
#              Preto e branco
#             </label>
#             <div class="color_filter bg_colors">
#              <input id="cf_red" name="colors" type="checkbox" value="red">
#               <label class="red" for="cf_red">
#               </label>
#               <input id="cf_orange" name="colors" type="checkbox" value="orange">
#                <label class="orange" for="cf_orange">
#                </label>
#                <input id="cf_yellow" name="colors" type="checkbox" value="yellow">
#                 <label class="yellow" for="cf_yellow">
#                 </label>
#                 <input id="cf_green" name="colors" type="checkbox" value="green">
#                  <label class="green" for="cf_green">
#                  </label>
#                  <input id="cf_turquoise" name="colors" type="checkbox" value="turquoise">
#                   <label class="turquoise" for="cf_turquoise">
#                   </label>
#                   <input id="cf_blue" name="colors" type="checkbox" value="blue">
#                    <label class="blue" for="cf_blue">
#                    </label>
#                    <input id="cf_lilac" name="colors" type="checkbox" value="lilac">
#                     <label class="lilac" for="cf_lilac">
#                     </label>
#                     <input id="cf_pink" name="colors" type="checkbox" value="pink">
#                      <label class="pink" for="cf_pink">
#                      </label>
#                      <input id="cf_white" name="colors" type="checkbox" value="white">
#                       <label class="white" for="cf_white">
#                       </label>
#                       <input id="cf_gray" name="colors" type="checkbox" value="gray">
#                        <label class="gray" for="cf_gray">
#                        </label>
#                        <input id="cf_black" name="colors" type="checkbox" value="black">
#                         <label class="black" for="cf_black">
#                         </label>
#                         <input id="cf_brown" name="colors" type="checkbox" value="brown">
#                          <label class="brown" for="cf_brown">
#                          </label>
#                         </input>
#                        </input>
#                       </input>
#                      </input>
#                     </input>
#                    </input>
#                   </input>
#                  </input>
#                 </input>
#                </input>
#               </input>
#              </input>
#             </div>
#            </input>
#           </td>
#          </tr>
#          <tr class="video_option">
#           <th>
#            Resolução
#           </th>
#           <td>
#            <label>
#             <input name="resolution_4k" type="checkbox" value="1">
#              4K (2160p)
#             </input>
#            </label>
#            <label>
#             <input name="resolution_hd" type="checkbox" value="1">
#              HD (1080p)
#             </input>
#            </label>
#           </td>
#          </tr>
#          <tr>
#           <th style="font-weight:normal">
#            <a href="#" onclick="$('#search_syntax').slideToggle(200);return false;">
#             mais...
#            </a>
#           </th>
#           <td style="min-width:200px;max-width:250px">
#            <div id="search_syntax" style="display:none;white-space:normal">
#             Você pode usar AND, OR, NOT e () para refinar seus resultados de busca:
#             <p style="white-space:nowrap">
#              <i>
#               flower AND (red OR blue) NOT rose
#              </i>
#             </p>
#             Procure nos portifólios do usuário:
#             <div style="white-space:nowrap">
#              <i>
#               user:stux flower
#              </i>
#             </div>
#            </div>
#           </td>
#          </tr>
#         </table>
#        </div>
#        <div>
#         <input data-autofocus="" name="q" placeholder="Procurar imagens, vetores e videos" type="text" value="gatinhos felizes">
#          <input name="order" type="hidden" value="popular"/>
#         </input>
#        </div>
#       </input>
#      </form>
#     </div>
#    </div>
#    <div class="clearfix" id="content">
#     <div class="media_list">
#      <div style="border-bottom:1px solid #f0f1f4">
#       <div style="max-width:1788px;margin:10px auto 0;padding:0 20px">
#        <div class="hide-xs hide-sm">
#         <div class="paginator" style="float:right;position:relative;left:2px">
#          <a class="dd_box hover_opacity inverted hide-xs" href="#" style="position:relative;top:4px;margin-right:15px">
#           <i class="icon icon_options">
#           </i>
#          </a>
#          <div>
#           <table style="white-space:nowrap">
#            <tr>
#             <td>
#              Por página
#             </td>
#             <td>
#              <a href="/pt/photos/?q=gatinhos+felizes&amp;per_page=50">
#               50
#              </a>
#              <b>
#               100
#              </b>
#              <a href="/pt/photos/?q=gatinhos+felizes&amp;per_page=150">
#               150
#              </a>
#             </td>
#            </tr>
#            <tr title="Filtrar resultados explícitos">
#             <td>
#              SafeSearch
#             </td>
#             <td>
#              <input class="toggle_g_rated" type="checkbox"/>
#             </td>
#            </tr>
#           </table>
#          </div>
#          <form action="." class="add_search_params pure-form hide-xs hide-sm hide-md" method="get" style="display:inline-block">
#           <input name="pagi" style="width:10px" type="text" value="1">
#            / 1
#           </input>
#          </form>
#          <span class="pure-button pure-button-disabled">
#           <i>
#            ‹
#           </i>
#          </span>
#          <span class="pure-button pure-button-disabled">
#           <i>
#            ›
#           </i>
#          </span>
#         </div>
#        </div>
#        <div class="media_filter">
#         <span class="dd_box menu" style="padding:5px 10px;background:#eee;border-radius:2px" title="Ordenar por">
#          <b>
#           Popular
#          </b>
#          <i class="arrow">
#          </i>
#         </span>
#         <div>
#          <a href="/pt/photos/?q=gatinhos+felizes&amp;order=latest">
#           Último
#          </a>
#          <a href="/pt/photos/?q=gatinhos+felizes&amp;order=popular">
#           Popular
#           <i class="check">
#            ✓
#           </i>
#          </a>
#          <a href="/pt/photos/?q=gatinhos+felizes&amp;order=ec">
#           Escolha do Editor
#          </a>
#         </div>
#         <span class="dd_box menu">
#          Todas as imagens
#          <i class="arrow">
#          </i>
#         </span>
#         <div>
#          <a href="/pt/photos/?q=gatinhos+felizes&amp;image_type=all">
#           Todas as imagens
#           <i class="check">
#            ✓
#           </i>
#          </a>
#          <a href="/pt/photos/?q=gatinhos+felizes&amp;image_type=photo">
#           Fotos
#          </a>
#          <a href="/pt/photos/?q=gatinhos+felizes&amp;image_type=vector">
#           Imagens vetoriais
#          </a>
#          <a href="/pt/photos/?q=gatinhos+felizes&amp;image_type=illustration">
#           Ilustrações
#          </a>
#          <a href="/pt/videos/list/?q=gatinhos%20felizes&amp;order=popular">
#           Videos
#          </a>
#         </div>
#         <span class="dd_box menu">
#          Orientação
#          <i class="arrow">
#          </i>
#         </span>
#         <div>
#          <a href="/pt/photos/?q=gatinhos+felizes">
#           Qualquer orientação
#           <i class="check">
#            ✓
#           </i>
#          </a>
#          <a href="/pt/photos/?q=gatinhos+felizes&amp;orientation=horizontal">
#           Horizontal
#          </a>
#          <a href="/pt/photos/?q=gatinhos+felizes&amp;orientation=vertical">
#           Vertical
#          </a>
#         </div>
#         <span class="dd_box menu">
#          Categoria
#          <i class="arrow">
#          </i>
#         </span>
#         <div id="cat_filter">
#         </div>
#         <form action="." class="add_search_params filter" method="get" style="display:inline-block">
#          <span class="dd_box menu">
#           Tamanho
#           <i class="arrow">
#           </i>
#          </span>
#          <div style="padding:10px 15px 15px">
#           <div class="pure-form">
#            <p style="margin:0 0 5px">
#             Maior que
#            </p>
#            <input class="min_width_height" name="min_width" placeholder="Largura" type="text" value="">
#             <i class="times" style="font-size:14px;margin:0 3px">
#              ×
#             </i>
#             <input class="min_width_height" name="min_height" placeholder="Altura" type="text" value="">
#              px
#              <input class="pure-button button-md" style="padding:0 20px;line-height:28px;position:relative;top:-1px" type="submit" value="Vá">
#              </input>
#             </input>
#            </input>
#           </div>
#          </div>
#          <span class="dd_box menu">
#           Preto e branco
#           <i class="arrow">
#           </i>
#          </span>
#          <div style="padding:10px 15px 15px">
#           <label>
#            <input name="colors" type="checkbox" value="transparent">
#             Transparente
#            </input>
#           </label>
#           <input class="cf_grayscale" id="cf_grayscale_2" name="colors" style="float:none" type="checkbox" value="grayscale">
#            <label for="cf_grayscale_2" style="display:inline">
#             Preto e branco
#            </label>
#            <div class="color_filter bg_colors" style="width:140px;margin:4px 0 8px">
#             <input id="cf_red_2" name="colors" type="checkbox" value="red">
#              <label class="red" for="cf_red_2">
#              </label>
#              <input id="cf_orange_2" name="colors" type="checkbox" value="orange">
#               <label class="orange" for="cf_orange_2">
#               </label>
#               <input id="cf_yellow_2" name="colors" type="checkbox" value="yellow">
#                <label class="yellow" for="cf_yellow_2">
#                </label>
#                <input id="cf_green_2" name="colors" type="checkbox" value="green">
#                 <label class="green" for="cf_green_2">
#                 </label>
#                 <input id="cf_turquoise_2" name="colors" type="checkbox" value="turquoise">
#                  <label class="turquoise" for="cf_turquoise_2">
#                  </label>
#                  <input id="cf_blue_2" name="colors" type="checkbox" value="blue">
#                   <label class="blue" for="cf_blue_2">
#                   </label>
#                   <input id="cf_lilac_2" name="colors" type="checkbox" value="lilac">
#                    <label class="lilac" for="cf_lilac_2">
#                    </label>
#                    <input id="cf_pink_2" name="colors" type="checkbox" value="pink">
#                     <label class="pink" for="cf_pink_2">
#                     </label>
#                     <input id="cf_white_2" name="colors" type="checkbox" value="white">
#                      <label class="white" for="cf_white_2">
#                      </label>
#                      <input id="cf_gray_2" name="colors" type="checkbox" value="gray">
#                       <label class="gray" for="cf_gray_2">
#                       </label>
#                       <input id="cf_black_2" name="colors" type="checkbox" value="black">
#                        <label class="black" for="cf_black_2">
#                        </label>
#                        <input id="cf_brown_2" name="colors" type="checkbox" value="brown">
#                         <label class="brown" for="cf_brown_2">
#                         </label>
#                        </input>
#                       </input>
#                      </input>
#                     </input>
#                    </input>
#                   </input>
#                  </input>
#                 </input>
#                </input>
#               </input>
#              </input>
#             </input>
#            </div>
#            <input class="pure-button button-md" style="padding:0 20px;line-height:28px" type="submit" value="Vá">
#            </input>
#           </input>
#          </div>
#         </form>
#        </div>
#       </div>
#      </div>
#      <div style="background:#feffda">
#       <div style="max-width:1796px;margin:auto;padding:10px 20px 16px">
#        <div style="font-size:13px;color:#b0b17e;margin:0 7px">
#         Imagens patrocinadas
#        </div>
#        <div class="flex_grid sponsored" style="margin:2px 0 0">
#         <div class="item" data-h="329" data-w="450">
#          <a data-go="list-shutterstock&amp;id=352176329">
#           <img data-src="//image.shutterstock.com/display_pic_with_logo/3199406/352176329/stock-photo-cute-american-shorthair-cat-kitten-352176329.jpg" src="/static/img/blank.gif"/>
#          </a>
#         </div>
#         <div class="item" data-h="292" data-w="450">
#          <a data-go="list-shutterstock&amp;id=235089946">
#           <img data-src="//image.shutterstock.com/display_pic_with_logo/154447/235089946/stock-photo-cute-little-red-kitten-sleeps-on-fur-white-blanket-235089946.jpg" src="/static/img/blank.gif"/>
#          </a>
#         </div>
#         <div class="item" data-h="291" data-w="450">
#          <a data-go="list-shutterstock&amp;id=499242385">
#           <img data-src="//image.shutterstock.com/display_pic_with_logo/274816/499242385/stock-photo-group-of-small-striped-kittens-in-an-old-basket-with-balls-of-yarn-499242385.jpg" src="/static/img/blank.gif"/>
#          </a>
#         </div>
#         <div class="item" data-h="292" data-w="450">
#          <a data-go="list-shutterstock&amp;id=421456408">
#           <img data-src="//image.shutterstock.com/display_pic_with_logo/156673/421456408/stock-photo-kittens-and-mittens-white-red-and-grey-newborn-kittens-in-a-plaid-blanket-sweet-adorable-tiny-421456408.jpg" src="/static/img/blank.gif"/>
#          </a>
#         </div>
#         <div class="item" data-h="301" data-w="450">
#          <a data-go="list-shutterstock&amp;id=394050538">
#           <img data-src="//image.shutterstock.com/display_pic_with_logo/948934/394050538/stock-photo-kitten-playing-with-soap-bubbles-on-green-field-in-summer-side-view-394050538.jpg" src="/static/img/blank.gif"/>
#          </a>
#         </div>
#         <div class="item" data-h="292" data-w="450">
#          <a data-go="list-shutterstock&amp;id=433559329">
#           <img data-src="//image.shutterstock.com/display_pic_with_logo/156673/433559329/stock-photo-funny-kitten-ginger-kitten-with-white-chest-long-haired-red-orange-kitten-sweet-adorable-kitten-433559329.jpg" src="/static/img/blank.gif"/>
#          </a>
#         </div>
#         <div class="item" data-h="292" data-w="450">
#          <a data-go="list-shutterstock&amp;id=321007298">
#           <img data-src="//image.shutterstock.com/display_pic_with_logo/154447/321007298/stock-photo-cute-little-ginger-kitten-is-sleeping-in-soft-blanket-on-wooden-floor-321007298.jpg" src="/static/img/blank.gif"/>
#          </a>
#         </div>
#         <div class="item" data-h="292" data-w="450">
#          <a data-go="list-shutterstock&amp;id=321007277">
#           <img data-src="//image.shutterstock.com/display_pic_with_logo/154447/321007277/stock-photo-cute-little-ginger-kitten-is-sleeping-in-soft-blanket-on-wooden-floor-321007277.jpg" src="/static/img/blank.gif"/>
#          </a>
#         </div>
#         <div class="item" data-h="292" data-w="450">
#          <a data-go="list-shutterstock&amp;id=466701878">
#           <img data-src="//image.shutterstock.com/display_pic_with_logo/813928/466701878/stock-photo-playful-red-kitten-on-a-white-background-isolated-466701878.jpg" src="/static/img/blank.gif"/>
#          </a>
#         </div>
#         <div class="item" data-h="292" data-w="450">
#          <a data-go="list-shutterstock&amp;id=507456550">
#           <img data-src="//image.shutterstock.com/display_pic_with_logo/64681/507456550/stock-photo-happy-kitten-likes-being-stroked-by-woman-s-hand-the-british-shorthair-507456550.jpg" src="/static/img/blank.gif"/>
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div style="background:#f7f8fa">
#       <div style="max-width:1824px;padding:10px 3px 20px;margin:auto">
#        <h1 class="hide-xs" style="font-size:13px;color:#bbb;margin:0 19px">
#         85 Imagens gratis - Fotos, Ilustrações, Imagens vetoriais:
#         <b>
#          Gatinhos, Felizes
#         </b>
#        </h1>
#        <div class="flex_grid credits" id="photo_grid" style="margin:4px 14px 0 15px">
#         <div class="item" data-h="572" data-w="640">
#          <a href="/pt/gatos-gatinhos-animal-30746/">
#           <img alt="Gatos, Gatinhos, Animal" src="https://cdn.pixabay.com/photo/2012/04/12/21/36/cats-30746__340.png" srcset="https://cdn.pixabay.com/photo/2012/04/12/21/36/cats-30746__340.png 1x, https://cdn.pixabay.com/photo/2012/04/12/21/36/cats-30746__480.png 2x" title="Gatos, Gatinhos, Animal"/>
#          </a>
#          <div>
#           <div class="counts hide-xs hide-sm ">
#            <em class="ajax" data-href="/pt/photos/like/30746/">
#             <i class="icon icon_like">
#             </i>
#             52
#            </em>
#            <em class="ajax" data-href="/pt/accounts/favorite/photo/30746/">
#             <i class="icon icon_favorite">
#             </i>
#             27
#            </em>
#            <em data-location="/pt/gatos-gatinhos-animal-30746/#comments">
#             <i class="icon icon_comment">
#             </i>
#             4
#            </em>
#           </div>
#           <a href="/users/3736/">
#            Clker-Free-Vector-Images
#           </a>
#          </div>
#         </div>
#         <div class="item" data-h="640" data-w="353">
#          <a href="/pt/gato-animal-felino-kitty-orange-161284/">
#           <img alt="Gato, Animal, Felino, Kitty, Orange" src="https://cdn.pixabay.com/photo/2013/07/13/13/38/cat-161284__340.png" srcset="https://cdn.pixabay.com/photo/2013/07/13/13/38/cat-161284__340.png 1x, https://cdn.pixabay.com/photo/2013/07/13/13/38/cat-161284__480.png 2x" title="Gato, Animal, Felino, Kitty, Orange"/>
#          </a>
#          <div>
#           <div class="counts hide-xs hide-sm ">
#            <em class="ajax" data-href="/pt/photos/like/161284/">
#             <i class="icon icon_like">
#             </i>
#             12
#            </em>
#            <em class="ajax" data-href="/pt/accounts/favorite/photo/161284/">
#             <i class="icon icon_favorite">
#             </i>
#             17
#            </em>
#            <em data-location="/pt/gato-animal-felino-kitty-orange-161284/#comments">
#             <i class="icon icon_comment">
#             </i>
#             0
#            </em>
#           </div>
#           <a href="/users/30363/">
#            OpenClipart-Vectors
#           </a>
#          </div>
#         </div>
#         <div class="item" data-h="640" data-w="426">
#          <a href="/pt/gato-felino-gatinho-animal-bonito-2068614/">
#           <img alt="Gato, Felino, Gatinho, Animal, Bonito" src="https://cdn.pixabay.com/photo/2017/02/15/13/06/cat-2068614__340.jpg" srcset="https://cdn.pixabay.com/photo/2017/02/15/13/06/cat-2068614__340.jpg 1x, https://cdn.pixabay.com/photo/2017/02/15/13/06/cat-2068614__480.jpg 2x" title="Gato, Felino, Gatinho, Animal"/>
#          </a>
#          <div>
#           <div class="counts hide-xs hide-sm ">
#            <em class="ajax" data-href="/pt/photos/like/2068614/">
#             <i class="icon icon_like">
#             </i>
#             3
#            </em>
#            <em class="ajax" data-href="/pt/accounts/favorite/photo/2068614/">
#             <i class="icon icon_favorite">
#             </i>
#             2
#            </em>
#            <em data-location="/pt/gato-felino-gatinho-animal-bonito-2068614/#comments">
#             <i class="icon icon_comment">
#             </i>
#             0
#            </em>
#           </div>
#           <a href="/users/742747/">
#            milivanily
#           </a>
#          </div>
#         </div>
#         <div class="item" data-h="392" data-w="640">
#          <a href="/pt/gatinhos-gatos-foster-jogar-bonito-1534083/">
#           <img alt="Gatinhos, Gatos, Foster, Jogar, Bonito" src="https://cdn.pixabay.com/photo/2016/07/22/03/14/kittens-1534083__340.jpg" srcset="https://cdn.pixabay.com/photo/2016/07/22/03/14/kittens-1534083__340.jpg 1x, https://cdn.pixabay.com/photo/2016/07/22/03/14/kittens-1534083__480.jpg 2x" title="Gatinhos, Gatos, Foster, Jogar"/>
#          </a>
#          <div>
#           <div class="counts hide-xs hide-sm ">
#            <em class="ajax" data-href="/pt/photos/like/1534083/">
#             <i class="icon icon_like">
#             </i>
#             19
#            </em>
#            <em class="ajax" data-href="/pt/accounts/favorite/photo/1534083/">
#             <i class="icon icon_favorite">
#             </i>
#             14
#            </em>
#            <em data-location="/pt/gatinhos-gatos-foster-jogar-bonito-1534083/#comments">
#             <i class="icon icon_comment">
#             </i>
#             6
#            </em>
#           </div>
#           <a href="/users/165491/">
#            Mariamichelle
#           </a>
#          </div>
#         </div>
#         <div class="item" data-h="428" data-w="640">
#          <a href="/pt/gatinhos-gatos-foster-jogar-bonito-1534085/">
#           <img alt="Gatinhos, Gatos, Foster, Jogar, Bonito" src="https://cdn.pixabay.com/photo/2016/07/22/03/14/kittens-1534085__340.jpg" srcset="https://cdn.pixabay.com/photo/2016/07/22/03/14/kittens-1534085__340.jpg 1x, https://cdn.pixabay.com/photo/2016/07/22/03/14/kittens-1534085__480.jpg 2x" title="Gatinhos, Gatos, Foster, Jogar"/>
#          </a>
#          <div>
#           <div class="counts hide-xs hide-sm ">
#            <em class="ajax" data-href="/pt/photos/like/1534085/">
#             <i class="icon icon_like">
#             </i>
#             13
#            </em>
#            <em class="ajax" data-href="/pt/accounts/favorite/photo/1534085/">
#             <i class="icon icon_favorite">
#             </i>
#             9
#            </em>
#            <em data-location="/pt/gatinhos-gatos-foster-jogar-bonito-1534085/#comments">
#             <i class="icon icon_comment">
#             </i>
#             4
#            </em>
#           </div>
#           <a href="/users/165491/">
#            Mariamichelle
#           </a>
#          </div>
#         </div>
#         <div class="item" data-h="512" data-w="640">
#          <a href="/pt/gato-animal-de-estima%C3%A7%C3%A3o-animal-1898830/">
#           <img alt="Gato, Animal De Estimação, Animal" src="https://cdn.pixabay.com/photo/2016/12/11/05/35/cat-1898830__340.jpg" srcset="https://cdn.pixabay.com/photo/2016/12/11/05/35/cat-1898830__340.jpg 1x, https://cdn.pixabay.com/photo/2016/12/11/05/35/cat-1898830__480.jpg 2x" title="Gato, Animal De Estimação, Animal"/>
#          </a>
#          <div>
#           <div class="counts hide-xs hide-sm ">
#            <em class="ajax" data-href="/pt/photos/like/1898830/">
#             <i class="icon icon_like">
#             </i>
#             10
#            </em>
#            <em class="ajax" data-href="/pt/accounts/favorite/photo/1898830/">
#             <i class="icon icon_favorite">
#             </i>
#             9
#            </em>
#            <em data-location="/pt/gato-animal-de-estima%C3%A7%C3%A3o-animal-1898830/#comments">
#             <i class="icon icon_comment">
#             </i>
#             1
#            </em>
#           </div>
#           <a href="/users/3041026/">
#            bodhichita
#           </a>
#          </div>
#         </div>
#         <div class="item" data-h="640" data-w="424">
#          <a href="/pt/natureza-gato-animal-bonito-1802084/">
#           <img alt="Natureza, Gato, Animal, Bonito" src="https://cdn.pixabay.com/photo/2016/11/06/01/51/nature-1802084__340.jpg" srcset="https://cdn.pixabay.com/photo/2016/11/06/01/51/nature-1802084__340.jpg 1x, https://cdn.pixabay.com/photo/2016/11/06/01/51/nature-1802084__480.jpg 2x" title="Natureza, Gato, Animal, Bonito"/>
#          </a>
#          <div>
#           <div class="counts hide-xs hide-sm ">
#            <em class="ajax" data-href="/pt/photos/like/1802084/">
#             <i class="icon icon_like">
#             </i>
#             3
#            </em>
#            <em class="ajax" data-href="/pt/accounts/favorite/photo/1802084/">
#             <i class="icon icon_favorite">
#             </i>
#             2
#            </em>
#            <em data-location="/pt/natureza-gato-animal-bonito-1802084/#comments">
#             <i class="icon icon_comment">
#             </i>
#             0
#            </em>
#           </div>
#           <a href="/users/3694166/">
#            Gelyane
#           </a>
#          </div>
#         </div>
#         <div class="item" data-h="390" data-w="640">
#          <a href="/pt/gatos-animais-animal-de-estima%C3%A7%C3%A3o-1800942/">
#           <img alt="Gatos, Animais, Animal De Estimação" src="https://cdn.pixabay.com/photo/2016/11/05/18/53/cats-1800942__340.jpg" srcset="https://cdn.pixabay.com/photo/2016/11/05/18/53/cats-1800942__340.jpg 1x, https://cdn.pixabay.com/photo/2016/11/05/18/53/cats-1800942__480.jpg 2x" title="Gatos, Animais, Animal De Estimação"/>
#          </a>
#          <div>
#           <div class="counts hide-xs hide-sm ">
#            <em class="ajax" data-href="/pt/photos/like/1800942/">
#             <i class="icon icon_like">
#             </i>
#             13
#            </em>
#            <em class="ajax" data-href="/pt/accounts/favorite/photo/1800942/">
#             <i class="icon icon_favorite">
#             </i>
#             10
#            </em>
#            <em data-location="/pt/gatos-animais-animal-de-estima%C3%A7%C3%A3o-1800942/#comments">
#             <i class="icon icon_comment">
#             </i>
#             2
#            </em>
#           </div>
#           <a href="/users/1007570/">
#            JosepMonter
#           </a>
#          </div>
#         </div>
#         <div class="item" data-h="640" data-w="426">
#          <a href="/pt/gato-pessoa-jogar-691175/">
#           <img alt="Gato, Pessoa, Jogar, Animal De Estimação" src="https://cdn.pixabay.com/photo/2015/03/26/10/21/cat-691175__340.jpg" srcset="https://cdn.pixabay.com/photo/2015/03/26/10/21/cat-691175__340.jpg 1x, https://cdn.pixabay.com/photo/2015/03/26/10/21/cat-691175__480.jpg 2x" title="Gato, Pessoa, Jogar"/>
#          </a>
#          <div>
#           <div class="counts hide-xs hide-sm ">
#            <em class="ajax" data-href="/pt/photos/like/691175/">
#             <i class="icon icon_like">
#             </i>
#             54
#            </em>
#            <em class="ajax" data-href="/pt/accounts/favorite/photo/691175/">
#             <i class="icon icon_favorite">
#             </i>
#             78
#            </em>
#            <em data-location="/pt/gato-pessoa-jogar-691175/#comments">
#             <i class="icon icon_comment">
#             </i>
#             8
#            </em>
#           </div>
#           <a href="/users/242387/">
#            Unsplash
#           </a>
#          </div>
#         </div>
#         <div class="item" data-h="476" data-w="640">
#          <a href="/pt/gato-morim-felino-animal-bonito-1277662/">
#           <img alt="Gato, Morim, Felino, Animal, Bonito" src="https://cdn.pixabay.com/photo/2016/03/24/21/21/cat-1277662__340.jpg" srcset="https://cdn.pixabay.com/photo/2016/03/24/21/21/cat-1277662__340.jpg 1x, https://cdn.pixabay.com/photo/2016/03/24/21/21/cat-1277662__480.jpg 2x" title="Gato, Morim, Felino, Animal, Bonito"/>
#          </a>
#          <div>
#           <div class="counts hide-xs hide-sm ">
#            <em class="ajax" data-href="/pt/photos/like/1277662/">
#             <i class="icon icon_like">
#             </i>
#             17
#            </em>
#            <em class="ajax" data-href="/pt/accounts/favorite/photo/1277662/">
#             <i class="icon icon_favorite">
#             </i>
#             12
#            </em>
#            <em data-location="/pt/gato-morim-felino-animal-bonito-1277662/#comments">
#             <i class="icon icon_comment">
#             </i>
#             10
#            </em>
#           </div>
#           <a href="/users/165491/">
#            Mariamichelle
#           </a>
#          </div>
#         </div>
#         <div class="item" data-h="480" data-w="640">
#          <a href="/pt/gato-vermelho-gato-vermelho-1090145/">
#           <img alt="Gato, Vermelho, Gato Vermelho" src="https://cdn.pixabay.com/photo/2015/12/12/21/19/cat-1090145__340.jpg" srcset="https://cdn.pixabay.com/photo/2015/12/12/21/19/cat-1090145__340.jpg 1x, https://cdn.pixabay.com/photo/2015/12/12/21/19/cat-1090145__480.jpg 2x" title="Gato, Vermelho, Gato Vermelho"/>
#          </a>
#          <div>
#           <div class="counts hide-xs hide-sm ">
#            <em class="ajax" data-href="/pt/photos/like/1090145/">
#             <i class="icon icon_like">
#             </i>
#             7
#            </em>
#            <em class="ajax" data-href="/pt/accounts/favorite/photo/1090145/">
#             <i class="icon icon_favorite">
#             </i>
#             5
#            </em>
#            <em data-location="/pt/gato-vermelho-gato-vermelho-1090145/#comments">
#             <i class="icon icon_comment">
#             </i>
#             0
#            </em>
#           </div>
#           <a href="/users/2/">
#            Hans
#           </a>
#          </div>
#         </div>
#         <div class="item" data-h="456" data-w="640">
#          <a href="/pt/pin%C3%B3quio-figaro-walt-disney-2055824/">
#           <img alt="Pinóquio, Figaro, Walt Disney" src="https://cdn.pixabay.com/photo/2017/02/10/17/57/pinocchio-2055824__340.jpg" srcset="https://cdn.pixabay.com/photo/2017/02/10/17/57/pinocchio-2055824__340.jpg 1x, https://cdn.pixabay.com/photo/2017/02/10/17/57/pinocchio-2055824__480.jpg 2x" title="Pinóquio, Figaro, Walt Disney"/>
#          </a>
#          <div>
#           <div class="counts hide-xs hide-sm ">
#            <em class="ajax" data-href="/pt/photos/like/2055824/">
#             <i class="icon icon_like">
#             </i>
#             11
#            </em>
#            <em class="ajax" data-href="/pt/accounts/favorite/photo/2055824/">
#             <i class="icon icon_favorite">
#             </i>
#             10
#            </em>
#            <em data-location="/pt/pin%C3%B3quio-figaro-walt-disney-2055824/#comments">
#             <i class="icon icon_comment">
#             </i>
#             0
#            </em>
#           </div>
#           <a href="/users/586300/">
#            Natunika
#           </a>
#          </div>
#         </div>
#         <div class="item" data-h="454" data-w="640">
#          <a href="/pt/alice-no-pa%C3%ADs-das-maravilhas-2055885/">
#           <img alt="Alice No País Das Maravilhas" src="https://cdn.pixabay.com/photo/2017/02/10/18/11/alice-in-wonderland-2055885__340.jpg" srcset="https://cdn.pixabay.com/photo/2017/02/10/18/11/alice-in-wonderland-2055885__340.jpg 1x, https://cdn.pixabay.com/photo/2017/02/10/18/11/alice-in-wonderland-2055885__480.jpg 2x" title="Alice No País Das Maravilhas"/>
#          </a>
#          <div>
#           <div class="counts hide-xs hide-sm ">
#            <em class="ajax" data-href="/pt/photos/like/2055885/">
#             <i class="icon icon_like">
#             </i>
#             13
#            </em>
#            <em class="ajax" data-href="/pt/accounts/favorite/photo/2055885/">
#             <i class="icon icon_favorite">
#             </i>
#             8
#            </em>
#            <em data-location="/pt/alice-no-pa%C3%ADs-das-maravilhas-2055885/#comments">
#             <i class="icon icon_comment">
#             </i>
#             5
#            </em>
#           </div>
#           <a href="/users/586300/">
#            Natunika
#           </a>
#          </div>
#         </div>
#         <div class="item" data-h="640" data-w="517">
#          <a href="/pt/gato-animal-engra%C3%A7ado-bonito-1424748/">
#           <img alt="Gato, Animal, Engraçado, Bonito" src="https://cdn.pixabay.com/photo/2016/05/30/13/38/cat-1424748__340.png" srcset="https://cdn.pixabay.com/photo/2016/05/30/13/38/cat-1424748__340.png 1x, https://cdn.pixabay.com/photo/2016/05/30/13/38/cat-1424748__480.png 2x" title="Gato, Animal, Engraçado, Bonito"/>
#          </a>
#          <div>
#           <div class="counts hide-xs hide-sm ">
#            <em class="ajax" data-href="/pt/photos/like/1424748/">
#             <i class="icon icon_like">
#             </i>
#             23
#            </em>
#            <em class="ajax" data-href="/pt/accounts/favorite/photo/1424748/">
#             <i class="icon icon_favorite">
#             </i>
#             23
#            </em>
#            <em data-location="/pt/gato-animal-engra%C3%A7ado-bonito-1424748/#comments">
#             <i class="icon icon_comment">
#             </i>
#             2
#            </em>
#           </div>
#           <a href="/users/2641041/">
#            GraphicMama-team
#           </a>
#          </div>
#         </div>
#         <div class="item" data-h="640" data-w="640">
#          <a href="/pt/gato-bonito-olhos-intensa-stare-1256750/">
#           <img alt="Gato, Bonito, Olhos, Intensa, Stare" src="https://cdn.pixabay.com/photo/2016/03/15/01/53/cat-1256750__340.jpg" srcset="https://cdn.pixabay.com/photo/2016/03/15/01/53/cat-1256750__340.jpg 1x, https://cdn.pixabay.com/photo/2016/03/15/01/53/cat-1256750__480.jpg 2x" title="Gato, Bonito, Olhos, Intensa, Stare"/>
#          </a>
#          <div>
#           <div class="counts hide-xs hide-sm ">
#            <em class="ajax" data-href="/pt/photos/like/1256750/">
#             <i class="icon icon_like">
#             </i>
#             11
#            </em>
#            <em class="ajax" data-href="/pt/accounts/favorite/photo/1256750/">
#             <i class="icon icon_favorite">
#             </i>
#             7
#            </em>
#            <em data-location="/pt/gato-bonito-olhos-intensa-stare-1256750/#comments">
#             <i class="icon icon_comment">
#             </i>
#             0
#            </em>
#           </div>
#           <a href="/users/2219324/">
#            Shadesofnate
#           </a>
#          </div>
#         </div>
#         <div class="item" data-h="429" data-w="640">
#          <a href="/pt/crian%C3%A7a-jogue-feliz-crian%C3%A7as-489685/">
#           <img alt="Criança, Jogue, Feliz, Crianças" src="https://cdn.pixabay.com/photo/2014/10/15/14/25/child-489685__340.jpg" srcset="https://cdn.pixabay.com/photo/2014/10/15/14/25/child-489685__340.jpg 1x, https://cdn.pixabay.com/photo/2014/10/15/14/25/child-489685__480.jpg 2x" title="Criança, Jogue, Feliz, Crianças"/>
#          </a>
#          <div>
#           <div class="counts hide-xs hide-sm ">
#            <em class="ajax" data-href="/pt/photos/like/489685/">
#             <i class="icon icon_like">
#             </i>
#             38
#            </em>
#            <em class="ajax" data-href="/pt/accounts/favorite/photo/489685/">
#             <i class="icon icon_favorite">
#             </i>
#             55
#            </em>
#            <em data-location="/pt/crian%C3%A7a-jogue-feliz-crian%C3%A7as-489685/#comments">
#             <i class="icon icon_comment">
#             </i>
#             2
#            </em>
#           </div>
#           <a href="/users/406384/">
#            ThePixelman
#           </a>
#          </div>
#         </div>
#         <div class="item" data-h="426" data-w="640">
#          <a href="/pt/gato-amor-bonito-animal-gatinho-1052652/">
#           <img alt="Gato, Amor, Bonito, Animal, Gatinho" data-lazy="https://cdn.pixabay.com/photo/2015/11/20/09/25/cat-1052652__340.jpg" data-lazy-srcset="https://cdn.pixabay.com/photo/2015/11/20/09/25/cat-1052652__340.jpg 1x, https://cdn.pixabay.com/photo/2015/11/20/09/25/cat-1052652__480.jpg 2x" src="/static/img/blank.gif" title="Gato, Amor, Bonito, Animal, Gatinho"/>
#          </a>
#          <div>
#           <div class="counts hide-xs hide-sm ">
#            <em class="ajax" data-href="/pt/photos/like/1052652/">
#             <i class="icon icon_like">
#             </i>
#             4
#            </em>
#            <em class="ajax" data-href="/pt/accounts/favorite/photo/1052652/">
#             <i class="icon icon_favorite">
#             </i>
#             6
#            </em>
#            <em data-location="/pt/gato-amor-bonito-animal-gatinho-1052652/#comments">
#             <i class="icon icon_comment">
#             </i>
#             1
#            </em>
#           </div>
#           <a href="/users/1459433/">
#            stephenwd4h0
#           </a>
#          </div>
#         </div>
#         <div class="item" data-h="632" data-w="640">
#          <a href="/pt/gato-explora%C3%A7%C3%A3o-mouse-sorriso-1456741/">
#           <img alt="Gato, Exploração, Mouse, Sorriso" data-lazy="https://cdn.pixabay.com/photo/2016/06/14/14/53/cat-1456741__340.png" data-lazy-srcset="https://cdn.pixabay.com/photo/2016/06/14/14/53/cat-1456741__340.png 1x, https://cdn.pixabay.com/photo/2016/06/14/14/53/cat-1456741__480.png 2x" src="/static/img/blank.gif" title="Gato, Exploração, Mouse, Sorriso"/>
#          </a>
#          <div>
#           <div class="counts hide-xs hide-sm ">
#            <em class="ajax" data-href="/pt/photos/like/1456741/">
#             <i class="icon icon_like">
#             </i>
#             9
#            </em>
#            <em class="ajax" data-href="/pt/accounts/favorite/photo/1456741/">
#             <i class="icon icon_favorite">
#             </i>
#             12
#            </em>
#            <em data-location="/pt/gato-explora%C3%A7%C3%A3o-mouse-sorriso-1456741/#comments">
#             <i class="icon icon_comment">
#             </i>
#             0
#            </em>
#           </div>
#           <a href="/users/2641041/">
#            GraphicMama-team
#           </a>
#          </div>
#         </div>
#         <div class="item" data-h="423" data-w="640">
#          <a href="/pt/gato-fam%C3%ADlia-animal-de-estima%C3%A7%C3%A3o-727258/">
# ...
#             1
#            </em>
#            <em data-location="/pt/gato-tricolor-gato-colorido-1462044/#comments">
#             <i class="icon icon_comment">
#             </i>
#             0
#            </em>
#           </div>
#           <a href="/users/73994/">
#            shilmar
#           </a>
#          </div>
#         </div>
#         <div class="item" data-h="585" data-w="640">
#          <a href="/pt/resgate-malhado-gato-domesticado-916328/">
#           <img alt="Resgate, Malhado, Gato, Domesticado" data-lazy="https://cdn.pixabay.com/photo/2015/09/01/01/14/rescue-916328__340.jpg" data-lazy-srcset="https://cdn.pixabay.com/photo/2015/09/01/01/14/rescue-916328__340.jpg 1x, https://cdn.pixabay.com/photo/2015/09/01/01/14/rescue-916328__480.jpg 2x" src="/static/img/blank.gif" title="Resgate, Malhado, Gato, Domesticado"/>
#          </a>
#          <div>
#           <div class="counts hide-xs hide-sm ">
#            <em class="ajax" data-href="/pt/photos/like/916328/">
#             <i class="icon icon_like">
#             </i>
#             1
#            </em>
#            <em class="ajax" data-href="/pt/accounts/favorite/photo/916328/">
#             <i class="icon icon_favorite">
#             </i>
#             1
#            </em>
#            <em data-location="/pt/resgate-malhado-gato-domesticado-916328/#comments">
#             <i class="icon icon_comment">
#             </i>
#             0
#            </em>
#           </div>
#           <a href="/users/1338179/">
#            AppletonOnfoot
#           </a>
#          </div>
#         </div>
#         <div class="item" data-h="423" data-w="640">
#          <a href="/pt/gato-fam%C3%ADlia-animal-de-estima%C3%A7%C3%A3o-727265/">
#           <img alt="Gato, Família, Animal De Estimação, Amor" data-lazy="https://cdn.pixabay.com/photo/2015/04/17/13/59/cat-727265__340.jpg" data-lazy-srcset="https://cdn.pixabay.com/photo/2015/04/17/13/59/cat-727265__340.jpg 1x, https://cdn.pixabay.com/photo/2015/04/17/13/59/cat-727265__480.jpg 2x" src="/static/img/blank.gif" title="Gato, Família, Animal De Estimação"/>
#          </a>
#          <div>
#           <div class="counts hide-xs hide-sm ">
#            <em class="ajax" data-href="/pt/photos/like/727265/">
#             <i class="icon icon_like">
#             </i>
#             5
#            </em>
#            <em class="ajax" data-href="/pt/accounts/favorite/photo/727265/">
#             <i class="icon icon_favorite">
#             </i>
#             2
#            </em>
#            <em data-location="/pt/gato-fam%C3%ADlia-animal-de-estima%C3%A7%C3%A3o-727265/#comments">
#             <i class="icon icon_comment">
#             </i>
#             0
#            </em>
#           </div>
#           <a href="/users/941547/">
#            jonasjovaisis
#           </a>
#          </div>
#         </div>
#         <div class="item" data-h="640" data-w="480">
#          <a href="/pt/felino-gato-animal-de-estima%C3%A7%C3%A3o-648631/">
#           <img alt="Felino, Gato, Animal De Estimação" data-lazy="https://cdn.pixabay.com/photo/2015/02/25/11/48/feline-648631__340.jpg" data-lazy-srcset="https://cdn.pixabay.com/photo/2015/02/25/11/48/feline-648631__340.jpg 1x, https://cdn.pixabay.com/photo/2015/02/25/11/48/feline-648631__480.jpg 2x" src="/static/img/blank.gif" title="Felino, Gato, Animal De Estimação"/>
#          </a>
#          <div>
#           <div class="counts hide-xs hide-sm ">
#            <em class="ajax" data-href="/pt/photos/like/648631/">
#             <i class="icon icon_like">
#             </i>
#             14
#            </em>
#            <em class="ajax" data-href="/pt/accounts/favorite/photo/648631/">
#             <i class="icon icon_favorite">
#             </i>
#             11
#            </em>
#            <em data-location="/pt/felino-gato-animal-de-estima%C3%A7%C3%A3o-648631/#comments">
#             <i class="icon icon_comment">
#             </i>
#             8
#            </em>
#           </div>
#           <a href="/users/800104/">
#            Axe77
#           </a>
#          </div>
#         </div>
#         <div class="item" data-h="640" data-w="452">
#          <a href="/pt/sorvete-gato-desenho-arte-caneta-2066817/">
#           <img alt="Sorvete, Gato, Desenho, Arte, Caneta" data-lazy="https://cdn.pixabay.com/photo/2017/02/14/20/06/ice-cream-2066817__340.jpg" data-lazy-srcset="https://cdn.pixabay.com/photo/2017/02/14/20/06/ice-cream-2066817__340.jpg 1x, https://cdn.pixabay.com/photo/2017/02/14/20/06/ice-cream-2066817__480.jpg 2x" src="/static/img/blank.gif" title="Sorvete, Gato, Desenho, Arte"/>
#          </a>
#          <div>
#           <div class="counts hide-xs hide-sm ">
#            <em class="ajax" data-href="/pt/photos/like/2066817/">
#             <i class="icon icon_like">
#             </i>
#             0
#            </em>
#            <em class="ajax" data-href="/pt/accounts/favorite/photo/2066817/">
#             <i class="icon icon_favorite">
#             </i>
#             0
#            </em>
#            <em data-location="/pt/sorvete-gato-desenho-arte-caneta-2066817/#comments">
#             <i class="icon icon_comment">
#             </i>
#             0
#            </em>
#           </div>
#           <a href="/users/4168618/">
#            KaylinArt
#           </a>
#          </div>
#         </div>
#         <div class="item" data-h="640" data-w="452">
#          <a href="/pt/sorvete-gato-desenho-arte-caneta-2066810/">
#           <img alt="Sorvete, Gato, Desenho, Arte, Caneta" data-lazy="https://cdn.pixabay.com/photo/2017/02/14/20/01/ice-cream-2066810__340.png" data-lazy-srcset="https://cdn.pixabay.com/photo/2017/02/14/20/01/ice-cream-2066810__340.png 1x, https://cdn.pixabay.com/photo/2017/02/14/20/01/ice-cream-2066810__480.png 2x" src="/static/img/blank.gif" title="Sorvete, Gato, Desenho, Arte"/>
#          </a>
#          <div>
#           <div class="counts hide-xs hide-sm ">
#            <em class="ajax" data-href="/pt/photos/like/2066810/">
#             <i class="icon icon_like">
#             </i>
#             0
#            </em>
#            <em class="ajax" data-href="/pt/accounts/favorite/photo/2066810/">
#             <i class="icon icon_favorite">
#             </i>
#             1
#            </em>
#            <em data-location="/pt/sorvete-gato-desenho-arte-caneta-2066810/#comments">
#             <i class="icon icon_comment">
#             </i>
#             0
#            </em>
#           </div>
#           <a href="/users/4168618/">
#            KaylinArt
#           </a>
#          </div>
#         </div>
#         <div class="item" data-h="479" data-w="640">
#          <a href="/pt/gatinho-kitty-gato-borboleta-flor-1584664/">
#           <img alt="Gatinho, Kitty, Gato, Borboleta, Flor" data-lazy="https://cdn.pixabay.com/photo/2016/08/11/00/57/kitten-1584664__340.jpg" data-lazy-srcset="https://cdn.pixabay.com/photo/2016/08/11/00/57/kitten-1584664__340.jpg 1x, https://cdn.pixabay.com/photo/2016/08/11/00/57/kitten-1584664__480.jpg 2x" src="/static/img/blank.gif" title="Gatinho, Kitty, Gato, Borboleta"/>
#          </a>
#          <div>
#           <div class="counts hide-xs hide-sm ">
#            <em class="ajax" data-href="/pt/photos/like/1584664/">
#             <i class="icon icon_like">
#             </i>
#             0
#            </em>
#            <em class="ajax" data-href="/pt/accounts/favorite/photo/1584664/">
#             <i class="icon icon_favorite">
#             </i>
#             0
#            </em>
#            <em data-location="/pt/gatinho-kitty-gato-borboleta-flor-1584664/#comments">
#             <i class="icon icon_comment">
#             </i>
#             0
#            </em>
#           </div>
#           <a href="/users/2466641/">
#            cjhartz169
#           </a>
#          </div>
#         </div>
#         <div class="item" data-h="640" data-w="452">
#          <a href="/pt/sorvete-gato-desenho-arte-caneta-2066811/">
#           <img alt="Sorvete, Gato, Desenho, Arte, Caneta" data-lazy="https://cdn.pixabay.com/photo/2017/02/14/20/02/ice-cream-2066811__340.png" data-lazy-srcset="https://cdn.pixabay.com/photo/2017/02/14/20/02/ice-cream-2066811__340.png 1x, https://cdn.pixabay.com/photo/2017/02/14/20/02/ice-cream-2066811__480.png 2x" src="/static/img/blank.gif" title="Sorvete, Gato, Desenho, Arte"/>
#          </a>
#          <div>
#           <div class="counts hide-xs hide-sm ">
#            <em class="ajax" data-href="/pt/photos/like/2066811/">
#             <i class="icon icon_like">
#             </i>
#             0
#            </em>
#            <em class="ajax" data-href="/pt/accounts/favorite/photo/2066811/">
#             <i class="icon icon_favorite">
#             </i>
#             0
#            </em>
#            <em data-location="/pt/sorvete-gato-desenho-arte-caneta-2066811/#comments">
#             <i class="icon icon_comment">
#             </i>
#             0
#            </em>
#           </div>
#           <a href="/users/4168618/">
#            KaylinArt
#           </a>
#          </div>
#         </div>
#         <div class="item" data-h="640" data-w="452">
#          <a href="/pt/sorvete-gato-desenho-arte-caneta-2066809/">
#           <img alt="Sorvete, Gato, Desenho, Arte, Caneta" data-lazy="https://cdn.pixabay.com/photo/2017/02/14/20/01/ice-cream-2066809__340.png" data-lazy-srcset="https://cdn.pixabay.com/photo/2017/02/14/20/01/ice-cream-2066809__340.png 1x, https://cdn.pixabay.com/photo/2017/02/14/20/01/ice-cream-2066809__480.png 2x" src="/static/img/blank.gif" title="Sorvete, Gato, Desenho, Arte"/>
#          </a>
#          <div>
#           <div class="counts hide-xs hide-sm ">
#            <em class="ajax" data-href="/pt/photos/like/2066809/">
#             <i class="icon icon_like">
#             </i>
#             0
#            </em>
#            <em class="ajax" data-href="/pt/accounts/favorite/photo/2066809/">
#             <i class="icon icon_favorite">
#             </i>
#             0
#            </em>
#            <em data-location="/pt/sorvete-gato-desenho-arte-caneta-2066809/#comments">
#             <i class="icon icon_comment">
#             </i>
#             0
#            </em>
#           </div>
#           <a href="/users/4168618/">
#            KaylinArt
#           </a>
#          </div>
#         </div>
#         <div class="item" data-h="640" data-w="452">
#          <a href="/pt/sorvete-gato-desenho-arte-caneta-2066812/">
#           <img alt="Sorvete, Gato, Desenho, Arte, Caneta" data-lazy="https://cdn.pixabay.com/photo/2017/02/14/20/02/ice-cream-2066812__340.png" data-lazy-srcset="https://cdn.pixabay.com/photo/2017/02/14/20/02/ice-cream-2066812__340.png 1x, https://cdn.pixabay.com/photo/2017/02/14/20/02/ice-cream-2066812__480.png 2x" src="/static/img/blank.gif" title="Sorvete, Gato, Desenho, Arte"/>
#          </a>
#          <div>
#           <div class="counts hide-xs hide-sm ">
#            <em class="ajax" data-href="/pt/photos/like/2066812/">
#             <i class="icon icon_like">
#             </i>
#             0
#            </em>
#            <em class="ajax" data-href="/pt/accounts/favorite/photo/2066812/">
#             <i class="icon icon_favorite">
#             </i>
#             0
#            </em>
#            <em data-location="/pt/sorvete-gato-desenho-arte-caneta-2066812/#comments">
#             <i class="icon icon_comment">
#             </i>
#             0
#            </em>
#           </div>
#           <a href="/users/4168618/">
#            KaylinArt
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div style="border-top:1px solid #f0f1f4;max-width:1788px;margin:auto;padding:10px 20px 0">
#       <span id="paginator_clone" style="z-index:999;position:relative;top:-10px">
#       </span>
#       <div class="hide-xs hide-sm hide-md" style="position:relative;top:8px;left:2px;font-size:14px">
#        85 Imagens gratis - Fotos, Ilustrações, Imagens vetoriais:
#        <b>
#         Gatinhos, Felizes
#        </b>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div id="push">
#    </div>
#   </div>
#   <div id="footer">
#    <div id="footer_inner">
#     <div class="hover_links hide-xs hide-sm" style="float:right;margin:2px 0 0 30px">
#      <a href="https://www.facebook.com/pixabay" target="_blank">
#       <i class="icon icon_facebook">
#       </i>
#      </a>
#      <a href="https://twitter.com/pixabay" target="_blank">
#       <i class="icon icon_twitter">
#       </i>
#      </a>
#      <a href="https://plus.google.com/+Pixabay" target="_blank">
#       <i class="icon icon_google_plus">
#       </i>
#      </a>
#     </div>
#     <span style="margin-right:30px">
#      © 2017 Pixabay
#     </span>
#     <a class="dd_box menu hide-xs hide-sm hide-md" style="margin-right:30px">
#      Downloads grátis
#      <i class="arrow">
#      </i>
#     </a>
#     <div>
#      <a href="/pt/photos/">
#       Imagens gratis
#      </a>
#      <a href="/pt/photos/?image_type=photo">
#       Fotos gratis
#      </a>
#      <a href="/pt/photos/?image_type=vector">
#       Imagens vetoriais gratis
#      </a>
#      <a href="/pt/photos/?image_type=illustration">
#       Ilustrações gratis
#      </a>
#      <a href="/pt/videos/list/">
#       Vídeos grátis
#      </a>
#     </div>
#     <a class="dd_box menu langs" style="margin-right:30px">
#      Language
#      <i class="arrow">
#      </i>
#     </a>
#     <div>
#      <a href="/cs/">
#       Čeština
#      </a>
#      <a href="/da/">
#       Dansk
#      </a>
#      <a href="/de/">
#       Deutsch
#      </a>
#      <a href="/en/">
#       English
#      </a>
#      <a href="/es/">
#       Español
#      </a>
#      <a href="/fr/">
#       Français
#      </a>
#      <a href="/id/">
#       Indonesia
#      </a>
#      <a href="/it/">
#       Italiano
#      </a>
#      <a href="/hu/">
#       Magyar
#      </a>
#      <a href="/nl/">
#       Nederlands
#      </a>
#      <a href="/no/">
#       Norsk
#      </a>
#      <a href="/pl/">
#       Polski
#      </a>
#      <a href="/pt/">
#       Português
#      </a>
#      <a href="/ro/">
#       Română
#      </a>
#      <a href="/sk/">
#       Slovenčina
#      </a>
#      <a href="/fi/">
#       Suomi
#      </a>
#      <a href="/sv/">
#       Svenska
#      </a>
#      <a href="/tr/">
#       Türkçe
#      </a>
#      <a href="/vi/">
#       Việt
#      </a>
#      <a href="/th/">
#       ไทย
#      </a>
#      <a href="/bg/">
#       Български
#      </a>
#      <a href="/ru/">
#       Русский
#      </a>
#      <a href="/el/">
#       Ελληνική
#      </a>
#      <a href="/ja/">
#       日本語
#      </a>
#      <a href="/ko/">
#       한국어
#      </a>
#      <a href="/zh/">
#       简体中文
#      </a>
#     </div>
#     <a class="dd_box menu" style="margin-right:30px">
#      Serviço
#      <i class="arrow">
#      </i>
#     </a>
#     <div style="min-width:80px">
#      <a href="/pt/blog/">
#       Blog
#      </a>
#      <a href="/pt/forum/">
#       Fórum
#      </a>
#      <a href="/pt/service/about/">
#       Sobre nós
#      </a>
#      <a href="/pt/service/privacy/">
#       Política de Privacidade
#      </a>
#     </div>
#     <a href="/api/docs/" style="margin-right:30px">
#      API
#     </a>
#     <a href="/pt/service/faq/" style="margin-right:30px">
#      FAQ
#     </a>
#     <a href="/pt/service/terms/">
#      Termos de Serviço
#     </a>
#    </div>
#   </div>
#   <div id="fb-root">
#   </div>
#   <a id="toTop">
#    ▲
#   </a>
#   <script src="//ajax.googleapis.com/ajax/libs/jquery/1.11.3/jquery.min.js">
#   </script>
#   <script>
#    window.jQuery || document.write('<script src="/static/js/jquery.js"><\/script>');
#     var LANG = 'pt', I18N_DELETE = 'Apagar definitivamente?';
#   </script>
#   <script src="/static/js/base60.min.js">
#   </script>
#   <script>
#    var s = '', base_url = "/pt/photos/?q=gatinhos+felizes&amp;cat=val", tq = 'gatinhos felizes';
#         if (tq) $('#photo_grid img').click(function(){ setCookie('track_q', tq, 0, 2); });
#         $('.header_search [name="cat"] option').each(function(){ s += '<a href="'+base_url.replace('cat=val', 'cat='+this.value)+'">'+this.text+($(this).is(':selected')?' <i class="check">✓</i>':'')+'</a>'; });
#         $('#cat_filter').html(s);
#         $('.header_search').find('input[type="text"], input:checked, select, input[type="hidden"]').each(function(){
#             var i = this;
#             $('.add_search_params').each(function(){
#                 if (i.value && (!$(this).hasClass('filter') || i.name != 'colors' && i.name != 'min_width' && i.name != 'min_height'))
#                     $(this).append($('<input type="hidden" name="'+i.name+'">').val(i.value));
#             });
#         });
#   </script>
#  </body>
# </html>

# %% [markdown]
# ## Exercício 2
#
# Vamos aproveitar que já estamos nos sites de imagens de gatinhos, e baixar as 5 primeiras imagens de gatinhos. Nunca se sabe quando você vai precisar de imagens de gatinhos fofos na sua vida.

# %%
import shutil
import requests
from bs4 import BeautifulSoup

url = 'https://pixabay.com/pt/photos/'
payload = {'q': 'gatinhos felizes'}

r = requests.get(url, params=payload)
soup = BeautifulSoup(r.content, 'html.parser')

divs = soup.find('div', {'id': 'photo_grid'}).contents
i = 0
while i <= 3:
    img = divs[i].a.img
    if img.get('data-lazy'):
        img_url = img.get('data-lazy')
    elif img.get('src'):
        img_url = img.get('src')
    
    response = requests.get(img_url, stream=True)
    
    f = open('%d.png' % i, 'wb')
    shutil.copyfileobj(response.raw, f)
    f.close()
    
    i = i + 1

# %% [markdown]
# ## Exercício 3
#
# Imagino que todo mundo já encomendou alguma coisa pela internet. Eu gosto muito de uma interface bem limpa para receber encomenda, ou seja, só me importa aonde a encomenda tá agora, tanto faz o que já aconteceu com ela. A Correios disponibilizou uma API pública para realizar esse tipo de consulta, então vamos usufruir dela.

# %%
import requests
from bs4 import BeautifulSoup

url = 'http://websro.correios.com.br/sro_bin/txect01$.QueryList'
payload = {
    'P_LINGUA': '001',
    'P_TIPO': '001',
    'P_COD_UNI': 'OB035615101BR',
}

r = requests.get(url, params=payload)
soup = BeautifulSoup(r.content, 'html.parser')

situacao = soup.find_all('tr')[1]
hora, local, estado = situacao.find_all('td')
print(hora.string, local.string, estado.string)
# Out:
# 02/03/2017 11:57 CEE AGUA BRANCA - Sao Paulo/SP Entrega Efetuada

# %% [markdown]
# ## Exercício 4
#
# Agora para o nível magia negra do Python. Quero que instalem a biblioteca youtube_dl nos seus computadores e baixem um vídeo no Youtube. Para quem não conseguir achar como usa a youtube_dl ou tem muita preguiça, é isso (mostra o código). Só que como essa aula é de Web Scraping, então vou dificultar um pouco. Quero que vocês baixem imaginando que vocês resolveram procurar um vídeo na search bar do Youtube para baixar o vídeo que vocês querem (geralmente é o primeiro). Façam o código desde a url de busca.

# %%
import requests
from bs4 import BeautifulSoup
import youtube_dl

url = 'https://www.youtube.com'
payload = {
    'search_query': 'shape of you',
}

r = requests.get(url+'/results', params=payload)
soup = BeautifulSoup(r.content, 'html.parser')

tag = soup.find('a', {'rel': 'spf-prefetch'})
video_url = url + tag['href']

ydl_opts = {}
with youtube_dl.YoutubeDL(ydl_opts) as ydl:
    ydl.download([video_url])
